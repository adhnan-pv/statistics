# %%
import pandas as pd
import numpy as np

# %%
titanic=pd.read_csv(r"D:\data analyst\pandas_docs\titanic_final.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
group1=titanic.groupby("Sex")

# %%
group

# %%
gro1=group1["Survived"].sum()

# %%
gro1
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
gro2=group1['Sex'].sum()

# %%
gro2
# Out:
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
gro3=group1['Pclass'].sum()

# %%
gro3
# Out:
# Sex
# female     678
# male      1379
# Name: Pclass, dtype: int64

# %%
gro5=group1.sum().loc[:]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17480\3965528608.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gro5=group1.sum().loc[:]

# %%
gro5
# Out:
#         PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       135343       233     678   7286.00    218    204  13966.6628
# male         262043       109    1379  13919.17    248    136  14727.2865

# %%
gro6=group1.sum().loc[:]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17480\1009291509.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gro6=group1.sum().loc[:]

# %%
gro6
# Out:
#         PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       135343       233     678   7286.00    218    204  13966.6628
# male         262043       109    1379  13919.17    248    136  14727.2865

# %%
gro7=group1['Fare'].mean()

# %%
gro7
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
gro8=group1['Fare'].sum()

# %%
gro8
# Out:
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
group2=titanic.groupby('Embarked')

# %%
gro9=group2["PassengerId"].sum()

# %%
gro9
# Out:
# Embarked
# C     74820
# Q     32178
# S    289496
# Name: PassengerId, dtype: int64

# %%
gro10=group2["Fare"].sum()

# %%
gro10
# Out:
# Embarked
# C    10072.2962
# Q     1022.2543
# S    17439.3988
# Name: Fare, dtype: float64

# %%
gro11=group2["Fare"].median()

# %%
gro11
# Out:
# Embarked
# C    29.70
# Q     7.75
# S    13.00
# Name: Fare, dtype: float64

# %%
gro12=group2["Fare"].mean()

# %%
gro12
# Out:
# Embarked
# C    59.954144
# Q    13.276030
# S    27.079812
# Name: Fare, dtype: float64

# %%
gro13=group2['Sex'].sum()

# %%
gro13
# Out:
# Embarked
# C    femalefemalefemalemalemalefemalemalemalefemale...
# Q    malemalefemalefemalefemalefemalemalefemalefema...
# S    malefemalefemalemalemalemalefemalefemalefemale...
# Name: Sex, dtype: object

# %%
gro14=group2['Pclass'].sum()

# %%
gro14
# Out:
# Embarked
# C     317
# Q     224
# S    1514
# Name: Pclass, dtype: int64

# %%
gro15=group2['Survived'].sum()

# %%
gro15
# Out:
# Embarked
# C     93
# Q     30
# S    217
# Name: Survived, dtype: int64

# %%
iris=pd.read_csv("D:\data analyst\pandas_docs\seaborn\seaborn-data\iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
group3=iris.groupby('species')

# %%
group3

# %%
gro16=group3['sepal_length'].sum()

# %%
gro16
# Out:
# species
# setosa        250.3
# versicolor    296.8
# virginica     329.4
# Name: sepal_length, dtype: float64

# %%
gro17=group3['sepal_length'].mean()

# %%
gro17
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
gro18=group3["sepal_width"].sum()

# %%
gro18
# Out:
# species
# setosa        171.4
# versicolor    138.5
# virginica     148.7
# Name: sepal_width, dtype: float64

# %%
gro19=group3["sepal_width"].median()

# %%
gro19
# Out:
# species
# setosa        3.4
# versicolor    2.8
# virginica     3.0
# Name: sepal_width, dtype: float64

# %%
gro20=group3["sepal_width"].mean()

# %%
gro20
# Out:
# species
# setosa        3.428
# versicolor    2.770
# virginica     2.974
# Name: sepal_width, dtype: float64

# %%
gro21=group3.sum().loc[:]

# %%
gro21
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        171.4          73.1         12.3
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %%
flights=pd.read_csv(r"D:\data analyst\pandas_docs\seaborn\seaborn-data\flights.csv")

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
group4=flights.groupby(['month','year'])

# %%
group4

# %%
gro22=group4['passengers'].sum().loc[:]

# %%
gro22
# Out:
# month      year
# April      1949    129
#            1950    135
#            1951    163
#            1952    181
#            1953    235
#                   ...
# September  1956    355
#            1957    404
#            1958    404
#            1959    463
#            1960    508
# Name: passengers, Length: 144, dtype: int64

# %%
tips=pd.read_csv(r"D:\data analyst\pandas_docs\seaborn\seaborn-data\tips.csv")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
group5=tips.groupby('smoker')

# %%
group5

# %%
gro23=group5['total_bill'].sum()

# %%
gro23
# Out:
# smoker
# No     2897.43
# Yes    1930.34
# Name: total_bill, dtype: float64

# %%
gro24=group5['size'].sum()

# %%
gro24
# Out:
# smoker
# No     403
# Yes    224
# Name: size, dtype: int64

# %%
group6=tips.groupby('time')

# %%
gro25=group6['total_bill'].sum()

# %%
gro25
# Out:
# time
# Dinner    3660.30
# Lunch     1167.47
# Name: total_bill, dtype: float64

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wheather=pd.read_csv("D:\data analyst\pandas_docs\wheather.csv")

# %%
wheather
# Out:
#           country     location_name  latitude  longitude         timezone  \
# 0     Afghanistan             Kabul     34.52      69.18       Asia/Kabul
# 1         Albania            Tirana     41.33      19.82    Europe/Tirane
# 2         Algeria           Algiers     36.76       3.05   Africa/Algiers
# 3         Andorra  Andorra La Vella     42.50       1.52   Europe/Andorra
# 4          Angola            Luanda     -8.84      13.23    Africa/Luanda
# ...           ...               ...       ...        ...              ...
# 9541    Venezuela           Caracas     10.50     -66.92  America/Caracas
# 9542      Vietnam             Hanoi     21.03     105.85     Asia/Bangkok
# 9543        Yemen             Sanaa     15.35      44.21        Asia/Aden
# 9544       Zambia            Lusaka    -15.42      28.28    Africa/Lusaka
# 9545     Zimbabwe            Harare    -17.82      31.04    Africa/Harare
#
#       last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
data=pd.read_csv("pandas_docs/billionaires.csv",encoding="latin-1")

# %%
data
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
data.shape
# Out:
# (2640, 35)

# %%
data.dtypes
# Out:
# rank                                            int64
# finalWorth                                      int64
# category                                       object
# personName                                     object
# age                                           float64
# country                                        object
# city                                           object
# source                                         object
# industries                                     object
# countryOfCitizenship                           object
# organization                                   object
# selfMade                                         bool
# status                                         object
# gender                                         object
# birthDate                                      object
# lastName                                       object
# firstName                                      object
# ...

# %%
data.isna()
# Out:
#        rank  finalWorth  category  personName    age  country   city  source  \
# 0     False       False     False       False  False    False  False   False
# 1     False       False     False       False  False    False  False   False
# 2     False       False     False       False  False    False  False   False
# 3     False       False     False       False  False    False  False   False
# 4     False       False     False       False  False    False  False   False
# ...     ...         ...       ...         ...    ...      ...    ...     ...
# 2635  False       False     False       False  False    False  False   False
# 2636  False       False     False       False  False    False  False   False
# 2637  False       False     False       False  False    False  False   False
# 2638  False       False     False       False  False    False  False   False
# 2639  False       False     False       False  False    False  False   False
#
# ...

# %%
data
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
sns.scatterplot(x="age",y="finalWorth",data=data,palette='rocket')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15048\1501920390.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x="age",y="finalWorth",data=data,palette='rocket')
# <Axes: xlabel='age', ylabel='finalWorth'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
taxis=pd.read_csv(r"D:\data analyst\pandas_docs\seaborn\seaborn-data\taxis.csv")

# %%
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
taxis.dtypes
# Out:
# pickup              object
# dropoff             object
# passengers           int64
# distance           float64
# fare               float64
# tip                float64
# tolls              float64
# total              float64
# color               object
# payment             object
# pickup_zone         object
# dropoff_zone        object
# pickup_borough      object
# dropoff_borough     object
# dtype: object

# %%
sns.catplot(x='payment',y="fare",data=taxis,kind='box')
